# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import pandas as pd
import matplotlib.pyplot as plt

from utils import get_links, get_data, transform

# %%
# get_links.exe()

# %%
# get_data.exe()

# %%
transform.exe()

# %%
player_data = json.load(open('data/semistructured.json', 'rb'))['Josh Allen']['data']

player_data.keys()
# Out:
# dict_keys(['header', 'season_stats', '2021_gamelog_stats', '2020_gamelog_stats', '2019_gamelog_stats'])

# %%
player_data['header']
# Out:
# {'draft': '2018_round_1_7',
#  'college': 'wyoming',
#  'ht': '6’5”',
#  'wt': '233',
#  'dob': '1996-05-21',
#  'age': '26',
#  'pos': 'quarterback',
#  'team': 'buffalo'}

# %%
pd.DataFrame(player_data['2021_gamelog_stats'])
# Out:
#    week   opp result  score cmp passing_att  cmp% passing_yard passing_td  \
# 0     1   PIT      L  16-23  30          51  58.8          270          1
# 1     2  @MIA      W   35-0  17          33  51.5          179          2
# 2     3   WAS      W  43-21  32          43  74.4          358          4
# 3     4   HOU      W   40-0  20          30  66.7          248          2
# 4     5   @KC      W  38-20  15          26  57.7          315          3
# 5     6  @TEN      L  31-34  35          47  74.5          353          3
# 6     8   MIA      W  26-11  29          42  69.0          249          2
# 7     9  @JAC      L    6-9  31          47  66.0          264          0
# 8    10  @NYJ      W  45-17  21          28  75.0          366          2
# 9    11   IND      L  15-41  21          35  60.0          209          2
# 10   12   @NO      W   31-6  23          28  82.1          260          4
# 11   13    NE      L  10-14  15          30  50.0          145          1
# ...

# %%
pd.DataFrame(player_data['2020_gamelog_stats'])
# Out:
#    week   opp result  score cmp passing_att  cmp% passing_yard passing_td  \
# 0     1   NYJ      W  27-17  33          46  71.7          312          2
# 1     2  @MIA      W  31-28  24          35  68.6          415          4
# 2     3   LAR      W  35-32  24          33  72.7          311          4
# 3     4   @LV      W  30-23  24          34  70.6          288          2
# 4     5  @TEN      L  16-42  26          41  63.4          263          2
# 5     6    KC      L  17-26  14          27  51.9          122          2
# 6     7  @NYJ      W  18-10  30          43  69.8          307          0
# 7     8    NE      W  24-21  11          18  61.1          154          0
# 8     9   SEA      W  44-34  31          38  81.6          415          3
# 9    10  @ARI      L  30-32  32          49  65.3          284          2
# 10   12   LAC      W  27-17  18          24  75.0          157          1
# 11   13   @SF      W  34-24  32          40  80.0          375          4
# ...

# %%
pd.DataFrame(player_data['2019_gamelog_stats'])
# Out:
#    week   opp result  score cmp passing_att  cmp% passing_yard passing_td  \
# 0     1  @NYJ      W  17-16  24          37  64.9          254          1
# 1     2  @NYG      W  28-14  19          30  63.3          253          1
# 2     3   CIN      W  21-17  23          36  63.9          243          1
# 3     4    NE      L  10-16  13          28  46.4          153          0
# 4     5  @TEN      W   14-7  23          32  71.9          219          2
# 5     7   MIA      W  31-21  16          26  61.5          202          2
# 6     8   PHI      L  13-31  16          34  47.1          169          2
# 7     9   WAS      W   24-9  14          20  70.0          160          1
# 8    10  @CLE      L  16-19  22          41  53.7          266          0
# 9    11  @MIA      W  37-20  21          33  63.6          256          3
# 10   12   DEN      W   20-3  15          25  60.0          185          2
# 11   13  @DAL      W  26-15  19          24  79.2          231          1
# ...
